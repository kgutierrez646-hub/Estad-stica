# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar archivo CSV
df = pd.read_csv("Nacimientos.csv")

# Información básica
print("Información del dataset")
print(df.info())
print("Primeras filas del dataset")
print(df.head())
print("Resumen estadístico del dataset")
print(df.describe())
# Out:
# Información del dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16936 entries, 0 to 16935
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ANO                          16936 non-null  object
#  1   PERIODO DE REPORTE           16936 non-null  int64
#  2   SEXO                         16936 non-null  object
#  3   PESO (Gramos)                16936 non-null  object
#  4   TALLA (CentImetros)          16936 non-null  int64
#  5   FECHA NACIMIENTO             16936 non-null  object
#  6   PARTO ATENDIDO POR           16936 non-null  object
#  7   TIEMPO DE GESTACION          16929 non-null  float64
#  8   NUMERO CONSULTAS PRENATALES  16936 non-null  int64
#  9   TIPO PARTO                   16936 non-null  object
#  10  MULTIPLICIDAD EMBARAZO       16936 non-null  object
#  11  APGAR1                       16898 non-null  float64
#  12  APGAR2                       16898 non-null  float64
#  13  GRUPO SANGUINEO              16832 non-null  object
#  14  FACTOR RH                    16825 non-null  object
#  15  PERTENENCIA ETNICA           16936 non-null  object
#  16  EDAD MADRE                   16936 non-null  int64
#  17  ESTADO CONYUGAL MADRE        16742 non-null  object
#  18  NIVEL EDUCATIVO MADRE        16739 non-null  object
#  19  ULTIMO ANO APROBADO MADRE    16629 non-null  float64
#  20  PAIS RESIDENCIA              16936 non-null  object
#  21  DEPARTAMENTO RESIDENCIA      16931 non-null  object
#  22  MUNICIPIO RESIDENCIA         16931 non-null  object
#  23  AREA RESIDENCIA              16931 non-null  object
#  24  LOCALIDAD                    12356 non-null  object
#  25  NUMERO HIJOS NACIDOS VIVOS   16936 non-null  int64
#  26  NUMERO EMBARAZOS             16936 non-null  int64
#  27  REGIMEN SEGURIDAD            16936 non-null  object
#  28  NOMBRE ADMINISTRADORA        14638 non-null  object
#  29  EDAD PADRE                   16174 non-null  float64
#  30  NIVEL EDUCATIVO PADRE        14452 non-null  object
#  31  PROFESION CERTIFICADOR       16936 non-null  object
# dtypes: float64(5), int64(6), object(21)
# memory usage: 4.1+ MB
# None
# Primeras filas del dataset
#      ANO  PERIODO DE REPORTE       SEXO PESO (Gramos)  TALLA (CentImetros)  \
# 0  2,022                   1   FEMENINO         1,900                   42
# 1  2,022                   1   FEMENINO         2,240                   45
# 2  2,022                   1  MASCULINO         2,420                   46
# 3  2,022                   1  MASCULINO           810                   34
# 4  2,022                   1   FEMENINO         2,300                   44
#
#           FECHA NACIMIENTO PARTO ATENDIDO POR  TIEMPO DE GESTACION  \
# 0  2023 Mar 27 12:00:00 AM             MEDICO                 34.0
# 1  2023 Mar 25 12:00:00 AM             MEDICO                 37.0
# 2  2023 Mar 22 12:00:00 AM             MEDICO                 37.0
# 3  2023 Mar 07 12:00:00 AM             MEDICO                 26.0
# 4  2023 Mar 05 12:00:00 AM             MEDICO                 34.0
#
#    NUMERO CONSULTAS PRENATALES  TIPO PARTO  ... MUNICIPIO RESIDENCIA  \
# 0                            6  ESPONTANEO  ...               JARDIN
# 1                            4     CESAREA  ...              BETULIA
# 2                            8  ESPONTANEO  ...               ITAGÜI
# 3                            6  ESPONTANEO  ...              TAMESIS
# 4                            6     CESAREA  ...             MEDELLIN
#
#       AREA RESIDENCIA           LOCALIDAD NUMERO HIJOS NACIDOS VIVOS  \
# 0  CABECERA MUNICIPAL      RURAL DISPERSO                          1
# 1  CABECERA MUNICIPAL        SANTA TERESA                          4
# 2  CABECERA MUNICIPAL  BARRIO SAN GABRIEL                          1
# 3      RURAL DISPERSO                 NaN                          1
# 4  CABECERA MUNICIPAL               BELEN                          3
#
#   NUMERO EMBARAZOS REGIMEN SEGURIDAD  \
# 0                1      CONTRIBUTIVO
# 1                4      CONTRIBUTIVO
# 2                1      CONTRIBUTIVO
# 3                1      CONTRIBUTIVO
# 4                4        SUBSIDIADO
#
#                        NOMBRE ADMINISTRADORA EDAD PADRE NIVEL EDUCATIVO PADRE  \
# 0  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A        NaN                   NaN
# 1  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       34.0   TECNICA PROFESIONAL
# 2  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       19.0     BASICA SECUNDARIA
# 3  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       48.0       BASICA PRIMARIA
# 4  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       25.0     BASICA SECUNDARIA
#
#    PROFESION CERTIFICADOR
# 0                  MEDICO
# 1                  MEDICO
# 2                  MEDICO
# 3                  MEDICO
# 4                  MEDICO
#
# [5 rows x 32 columns]
# Resumen estadístico del dataset
#        PERIODO DE REPORTE  TALLA (CentImetros)  TIEMPO DE GESTACION  \
# count        16936.000000         16936.000000         16929.000000
# mean             2.388994            47.418458            37.790478
# std              1.071446             3.000083             2.225977
# min              1.000000            27.000000            24.000000
# 25%              1.000000            46.000000            37.000000
# 50%              2.000000            48.000000            38.000000
# 75%              3.000000            49.000000            39.000000
# max              4.000000            57.000000            42.000000
#
#        NUMERO CONSULTAS PRENATALES        APGAR1        APGAR2    EDAD MADRE  \
# count                 16936.000000  16898.000000  16898.000000  16936.000000
# mean                      6.706542      9.226772      9.510060     25.335085
# std                       3.099011      1.091456      0.877365      6.418784
# min                       0.000000      1.000000      1.000000     12.000000
# 25%                       5.000000      9.000000      9.000000     20.000000
# 50%                       7.000000      9.000000     10.000000     24.000000
# 75%                       8.000000     10.000000     10.000000     30.000000
# max                      24.000000     10.000000     10.000000     48.000000
#
#        ULTIMO ANO APROBADO MADRE  NUMERO HIJOS NACIDOS VIVOS  \
# count               16629.000000                16936.000000
# mean                    7.797763                    1.885038
# std                     3.137466                    1.183370
# min                     1.000000                    1.000000
# 25%                     6.000000                    1.000000
# 50%                     9.000000                    2.000000
# 75%                    11.000000                    2.000000
# max                    13.000000                   13.000000
#
#        NUMERO EMBARAZOS    EDAD PADRE
# count      16936.000000  16174.000000
# mean           2.119981     29.498269
# std            1.385918      7.884866
# min            1.000000     13.000000
# 25%            1.000000     24.000000
# 50%            2.000000     28.000000
# 75%            3.000000     34.000000
# max           14.000000    100.000000

# %%
# Valores faltantes
print("\nValores faltantes por columna:")
print(df.isnull().sum())

# Visualización de nulos
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de datos faltantes")
plt.show()
# Out:
# Valores faltantes por columna:
# ANO                               0
# PERIODO DE REPORTE                0
# SEXO                              0
# PESO (Gramos)                     0
# TALLA (CentImetros)               0
# FECHA NACIMIENTO                  0
# PARTO ATENDIDO POR                0
# TIEMPO DE GESTACION               7
# NUMERO CONSULTAS PRENATALES       0
# TIPO PARTO                        0
# MULTIPLICIDAD EMBARAZO            0
# APGAR1                           38
# APGAR2                           38
# GRUPO SANGUINEO                 104
# FACTOR RH                       111
# PERTENENCIA ETNICA                0
# EDAD MADRE                        0
# ESTADO CONYUGAL MADRE           194
# NIVEL EDUCATIVO MADRE           197
# ULTIMO ANO APROBADO MADRE       307
# PAIS RESIDENCIA                   0
# DEPARTAMENTO RESIDENCIA           5
# MUNICIPIO RESIDENCIA              5
# AREA RESIDENCIA                   5
# LOCALIDAD                      4580
# NUMERO HIJOS NACIDOS VIVOS        0
# NUMERO EMBARAZOS                  0
# REGIMEN SEGURIDAD                 0
# NOMBRE ADMINISTRADORA          2298
# EDAD PADRE                      762
# NIVEL EDUCATIVO PADRE          2484
# PROFESION CERTIFICADOR            0
# dtype: int64

# %%
# Valores faltantes
print("\nValores faltantes por columna:")
print(df.isnull().sum())

# Visualización de nulos
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de datos faltantes")
plt.show()
# Out:
# Valores faltantes por columna:
# ANO                               0
# PERIODO DE REPORTE                0
# SEXO                              0
# PESO (Gramos)                     0
# TALLA (CentImetros)               0
# FECHA NACIMIENTO                  0
# PARTO ATENDIDO POR                0
# TIEMPO DE GESTACION               7
# NUMERO CONSULTAS PRENATALES       0
# TIPO PARTO                        0
# MULTIPLICIDAD EMBARAZO            0
# APGAR1                           38
# APGAR2                           38
# GRUPO SANGUINEO                 104
# FACTOR RH                       111
# PERTENENCIA ETNICA                0
# EDAD MADRE                        0
# ESTADO CONYUGAL MADRE           194
# NIVEL EDUCATIVO MADRE           197
# ULTIMO ANO APROBADO MADRE       307
# PAIS RESIDENCIA                   0
# DEPARTAMENTO RESIDENCIA           5
# MUNICIPIO RESIDENCIA              5
# AREA RESIDENCIA                   5
# LOCALIDAD                      4580
# NUMERO HIJOS NACIDOS VIVOS        0
# NUMERO EMBARAZOS                  0
# REGIMEN SEGURIDAD                 0
# NOMBRE ADMINISTRADORA          2298
# EDAD PADRE                      762
# NIVEL EDUCATIVO PADRE          2484
# PROFESION CERTIFICADOR            0
# dtype: int64

# %%
df_cleaned = df.dropna()
print("Filas con datos faltantes eliminadas.")
print("Información del dataset después de eliminar valores faltantes:")
print(df_cleaned.info())
print("Primeras filas del dataset después de eliminar valores faltantes:")
print(df_cleaned.head())
# Out:
# Filas con datos faltantes eliminadas.
# Información del dataset después de eliminar valores faltantes:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8837 entries, 1 to 16934
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ANO                          8837 non-null   object
#  1   PERIODO DE REPORTE           8837 non-null   int64
#  2   SEXO                         8837 non-null   object
#  3   PESO (Gramos)                8837 non-null   object
#  4   TALLA (CentImetros)          8837 non-null   int64
#  5   FECHA NACIMIENTO             8837 non-null   object
#  6   PARTO ATENDIDO POR           8837 non-null   object
#  7   TIEMPO DE GESTACION          8837 non-null   float64
#  8   NUMERO CONSULTAS PRENATALES  8837 non-null   int64
#  9   TIPO PARTO                   8837 non-null   object
#  10  MULTIPLICIDAD EMBARAZO       8837 non-null   object
#  11  APGAR1                       8837 non-null   float64
#  12  APGAR2                       8837 non-null   float64
#  13  GRUPO SANGUINEO              8837 non-null   object
#  14  FACTOR RH                    8837 non-null   object
#  15  PERTENENCIA ETNICA           8837 non-null   object
#  16  EDAD MADRE                   8837 non-null   int64
#  17  ESTADO CONYUGAL MADRE        8837 non-null   object
#  18  NIVEL EDUCATIVO MADRE        8837 non-null   object
#  19  ULTIMO ANO APROBADO MADRE    8837 non-null   float64
#  20  PAIS RESIDENCIA              8837 non-null   object
#  21  DEPARTAMENTO RESIDENCIA      8837 non-null   object
#  22  MUNICIPIO RESIDENCIA         8837 non-null   object
#  23  AREA RESIDENCIA              8837 non-null   object
#  24  LOCALIDAD                    8837 non-null   object
#  25  NUMERO HIJOS NACIDOS VIVOS   8837 non-null   int64
#  26  NUMERO EMBARAZOS             8837 non-null   int64
#  27  REGIMEN SEGURIDAD            8837 non-null   object
#  28  NOMBRE ADMINISTRADORA        8837 non-null   object
#  29  EDAD PADRE                   8837 non-null   float64
#  30  NIVEL EDUCATIVO PADRE        8837 non-null   object
#  31  PROFESION CERTIFICADOR       8837 non-null   object
# dtypes: float64(5), int64(6), object(21)
# memory usage: 2.2+ MB
# None
# Primeras filas del dataset después de eliminar valores faltantes:
#      ANO  PERIODO DE REPORTE       SEXO PESO (Gramos)  TALLA (CentImetros)  \
# 1  2,022                   1   FEMENINO         2,240                   45
# 2  2,022                   1  MASCULINO         2,420                   46
# 4  2,022                   1   FEMENINO         2,300                   44
# 5  2,022                   1  MASCULINO         3,240                   50
# 7  2,022                   1   FEMENINO         2,820                   48
#
#           FECHA NACIMIENTO PARTO ATENDIDO POR  TIEMPO DE GESTACION  \
# 1  2023 Mar 25 12:00:00 AM             MEDICO                 37.0
# 2  2023 Mar 22 12:00:00 AM             MEDICO                 37.0
# 4  2023 Mar 05 12:00:00 AM             MEDICO                 34.0
# 5  2023 Mar 04 12:00:00 AM             MEDICO                 39.0
# 7  2023 Feb 26 12:00:00 AM             MEDICO                 40.0
#
#    NUMERO CONSULTAS PRENATALES  TIPO PARTO  ... MUNICIPIO RESIDENCIA  \
# 1                            4     CESAREA  ...              BETULIA
# 2                            8  ESPONTANEO  ...               ITAGÜI
# 4                            6     CESAREA  ...             MEDELLIN
# 5                            7  ESPONTANEO  ...                BELLO
# 7                            8  ESPONTANEO  ...                BELLO
#
#       AREA RESIDENCIA           LOCALIDAD NUMERO HIJOS NACIDOS VIVOS  \
# 1  CABECERA MUNICIPAL        SANTA TERESA                          4
# 2  CABECERA MUNICIPAL  BARRIO SAN GABRIEL                          1
# 4  CABECERA MUNICIPAL               BELEN                          3
# 5  CABECERA MUNICIPAL         LA GABRIELA                          1
# 7  CABECERA MUNICIPAL               BELLO                          1
#
#   NUMERO EMBARAZOS REGIMEN SEGURIDAD  \
# 1                4      CONTRIBUTIVO
# 2                1      CONTRIBUTIVO
# 4                4        SUBSIDIADO
# 5                2        SUBSIDIADO
# 7                1      CONTRIBUTIVO
#
#                        NOMBRE ADMINISTRADORA EDAD PADRE  \
# 1  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       34.0
# 2  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       19.0
# 4  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       25.0
# 5  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       27.0
# 7  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       26.0
#
#        NIVEL EDUCATIVO PADRE  PROFESION CERTIFICADOR
# 1        TECNICA PROFESIONAL                  MEDICO
# 2          BASICA SECUNDARIA                  MEDICO
# 4          BASICA SECUNDARIA                  MEDICO
# 5  MEDIA ACADEMICA O CLASICA                  MEDICO
# 7  MEDIA ACADEMICA O CLASICA                  MEDICO
#
# [5 rows x 32 columns]

# %%
# Visualización de nulos después de eliminar filas con NaN
sns.heatmap(df_cleaned.isnull(), cbar=False, cmap="viridis")
plt.title("Mapa de datos faltantes después de eliminar filas con NaN")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the 'PESO (Gramos)' column is numeric. If it's already converted, this line will not change its type again.
# If it hasn't been converted (e.g., if this cell is run independently), it will convert it.
# This check is important to prevent SettingWithCopyWarning if it was previously converted in a slice.
if df_cleaned['PESO (Gramos)'].dtype == 'object':
    df_cleaned['PESO (Gramos)'] = df_cleaned['PESO (Gramos)'].str.replace(',', '.').astype(float)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df_cleaned['PESO (Gramos)'], kde=True)
plt.title('Distribución de Peso (Gramos)')
plt.xlabel('Peso (Gramos)')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
sns.histplot(df_cleaned['TALLA (CentImetros)'], kde=True)
plt.title('Distribución de Talla (Centímetros)')
plt.xlabel('Talla (Centímetros)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-179696218.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['PESO (Gramos)'] = df_cleaned['PESO (Gramos)'].str.replace(',', '.').astype(float)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(y=df_cleaned['PESO (Gramos)'])
plt.title('Diagrama de Caja de Peso (Gramos)')
plt.ylabel('Peso (Gramos)')

plt.subplot(1, 2, 2)
sns.boxplot(y=df_cleaned['TALLA (CentImetros)'])
plt.title('Diagrama de Caja de Talla (Centímetros)')
plt.ylabel('Talla (Centímetros)')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Remove outliers from the `df_cleaned` DataFrame based on the 'PESO (Gramos)' and 'TALLA (CentImetros)' columns using the IQR method. This involves calculating Q1, Q3, and IQR for each column, then defining lower and upper bounds (Q1 - 1.5 * IQR, Q3 + 1.5 * IQR) to filter out the outliers. Display the shapes of the original `df_cleaned` and the final `df_no_outliers` DataFrames to show the number of rows removed, and display the first few rows of `df_no_outliers`.

# %% [markdown]
# ## Calculate IQR for 'PESO (Gramos)'
#
# ### Subtask:
# Calculate the first quartile (Q1), third quartile (Q3), and the Interquartile Range (IQR) for the 'PESO (Gramos)' column in the `df_cleaned` DataFrame.

# %% [markdown]
# **Reasoning**:
# Calculate the first quartile (Q1), third quartile (Q3), and the Interquartile Range (IQR) for the 'PESO (Gramos)' column in the `df_cleaned` DataFrame.

# %%
Q1_peso = df_cleaned['PESO (Gramos)'].quantile(0.25)
Q3_peso = df_cleaned['PESO (Gramos)'].quantile(0.75)
IQR_peso = Q3_peso - Q1_peso

print(f"Primer cuartil (Q1) para PESO (Gramos): {Q1_peso}")
print(f"Tercer cuartil (Q3) para PESO (Gramos): {Q3_peso}")
print(f"Rango intercuartílico (IQR) para PESO (Gramos): {IQR_peso}")
# Out:
# Primer cuartil (Q1) para PESO (Gramos): 2.67
# Tercer cuartil (Q3) para PESO (Gramos): 3.33
# Rango intercuartílico (IQR) para PESO (Gramos): 0.6600000000000001

# %% [markdown]
# **Reasoning**:
# Now, calculate the first quartile (Q1), third quartile (Q3), and the Interquartile Range (IQR) for the 'TALLA (CentImetros)' column in the `df_cleaned` DataFrame, similar to how it was done for 'PESO (Gramos)'.

# %%
Q1_talla = df_cleaned['TALLA (CentImetros)'].quantile(0.25)
Q3_talla = df_cleaned['TALLA (CentImetros)'].quantile(0.75)
IQR_talla = Q3_talla - Q1_talla

print(f"Primer cuartil (Q1) para TALLA (CentImetros): {Q1_talla}")
print(f"Tercer cuartil (Q3) para TALLA (CentImetros): {Q3_talla}")
print(f"Rango intercuartílico (IQR) para TALLA (CentImetros): {IQR_talla}")
# Out:
# Primer cuartil (Q1) para TALLA (CentImetros): 46.0
# Tercer cuartil (Q3) para TALLA (CentImetros): 50.0
# Rango intercuartílico (IQR) para TALLA (CentImetros): 4.0

# %% [markdown]
# **Reasoning**:
# Now that Q1, Q3, and IQR have been calculated for both 'PESO (Gramos)' and 'TALLA (CentImetros)', the next logical step is to define the lower and upper bounds for outlier detection using the IQR method (Q1 - 1.5 * IQR and Q3 + 1.5 * IQR) for both columns. This will allow for filtering out outliers in the subsequent step.

# %%
lower_bound_peso = Q1_peso - 1.5 * IQR_peso
upper_bound_peso = Q3_peso + 1.5 * IQR_peso

lower_bound_talla = Q1_talla - 1.5 * IQR_talla
upper_bound_talla = Q3_talla + 1.5 * IQR_talla

print(f"Límite inferior para PESO (Gramos): {lower_bound_peso}")
print(f"Límite superior para PESO (Gramos): {upper_bound_peso}")
print(f"Límite inferior para TALLA (CentImetros): {lower_bound_talla}")
print(f"Límite superior para TALLA (CentImetros): {upper_bound_talla}")
# Out:
# Límite inferior para PESO (Gramos): 1.6799999999999997
# Límite superior para PESO (Gramos): 4.32
# Límite inferior para TALLA (CentImetros): 40.0
# Límite superior para TALLA (CentImetros): 56.0

# %% [markdown]
# **Reasoning**:
# Now that the lower and upper bounds for outliers have been calculated for both 'PESO (Gramos)' and 'TALLA (CentImetros)', the next step is to filter the `df_cleaned` DataFrame to exclude rows that fall outside these bounds, creating a new DataFrame `df_no_outliers`. This will effectively remove the identified outliers.

# %%
df_no_outliers = df_cleaned[
    (df_cleaned['PESO (Gramos)'] >= lower_bound_peso) &
    (df_cleaned['PESO (Gramos)'] <= upper_bound_peso) &
    (df_cleaned['TALLA (CentImetros)'] >= lower_bound_talla) &
    (df_cleaned['TALLA (CentImetros)'] <= upper_bound_talla)
]

print(f"Shape of original df_cleaned: {df_cleaned.shape}")
print(f"Shape of df_no_outliers after removing outliers: {df_no_outliers.shape}")
print("Primeras filas del dataset sin valores atípicos:")
print(df_no_outliers.head())
# Out:
# Shape of original df_cleaned: (8837, 32)
# Shape of df_no_outliers after removing outliers: (8572, 32)
# Primeras filas del dataset sin valores atípicos:
#      ANO  PERIODO DE REPORTE       SEXO  PESO (Gramos)  TALLA (CentImetros)  \
# 1  2,022                   1   FEMENINO           2.24                   45
# 2  2,022                   1  MASCULINO           2.42                   46
# 4  2,022                   1   FEMENINO           2.30                   44
# 5  2,022                   1  MASCULINO           3.24                   50
# 7  2,022                   1   FEMENINO           2.82                   48
#
#           FECHA NACIMIENTO PARTO ATENDIDO POR  TIEMPO DE GESTACION  \
# 1  2023 Mar 25 12:00:00 AM             MEDICO                 37.0
# 2  2023 Mar 22 12:00:00 AM             MEDICO                 37.0
# 4  2023 Mar 05 12:00:00 AM             MEDICO                 34.0
# 5  2023 Mar 04 12:00:00 AM             MEDICO                 39.0
# 7  2023 Feb 26 12:00:00 AM             MEDICO                 40.0
#
#    NUMERO CONSULTAS PRENATALES  TIPO PARTO  ... MUNICIPIO RESIDENCIA  \
# 1                            4     CESAREA  ...              BETULIA
# 2                            8  ESPONTANEO  ...               ITAGÜI
# 4                            6     CESAREA  ...             MEDELLIN
# 5                            7  ESPONTANEO  ...                BELLO
# 7                            8  ESPONTANEO  ...                BELLO
#
#       AREA RESIDENCIA           LOCALIDAD NUMERO HIJOS NACIDOS VIVOS  \
# 1  CABECERA MUNICIPAL        SANTA TERESA                          4
# 2  CABECERA MUNICIPAL  BARRIO SAN GABRIEL                          1
# 4  CABECERA MUNICIPAL               BELEN                          3
# 5  CABECERA MUNICIPAL         LA GABRIELA                          1
# 7  CABECERA MUNICIPAL               BELLO                          1
#
#   NUMERO EMBARAZOS REGIMEN SEGURIDAD  \
# 1                4      CONTRIBUTIVO
# 2                1      CONTRIBUTIVO
# 4                4        SUBSIDIADO
# 5                2        SUBSIDIADO
# 7                1      CONTRIBUTIVO
#
#                        NOMBRE ADMINISTRADORA EDAD PADRE  \
# 1  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       34.0
# 2  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       19.0
# 4  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       25.0
# 5  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       27.0
# 7  EPS Y MEDICINA PREPAGADA SURAMERICANA S.A       26.0
#
#        NIVEL EDUCATIVO PADRE  PROFESION CERTIFICADOR
# 1        TECNICA PROFESIONAL                  MEDICO
# 2          BASICA SECUNDARIA                  MEDICO
# 4          BASICA SECUNDARIA                  MEDICO
# 5  MEDIA ACADEMICA O CLASICA                  MEDICO
# 7  MEDIA ACADEMICA O CLASICA                  MEDICO
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   For the 'PESO (Gramos)' column, the first quartile (Q1) was 2.67, the third quartile (Q3) was 3.33, and the Interquartile Range (IQR) was 0.66.
# *   Based on the IQR method, the lower bound for 'PESO (Gramos)' outliers was approximately 1.68, and the upper bound was 4.32.
# *   For the 'TALLA (CentImetros)' column, the first quartile (Q1) was 46.0, the third quartile (Q3) was 50.0, and the Interquartile Range (IQR) was 4.0.
# *   Based on the IQR method, the lower bound for 'TALLA (CentImetros)' outliers was 40.0, and the upper bound was 56.0.
# *   The original `df_cleaned` DataFrame contained 8837 rows and 32 columns.
# *   After removing outliers, the `df_no_outliers` DataFrame contains 8572 rows and 32 columns, indicating that 265 rows were identified and removed as outliers.
#
# ### Insights or Next Steps
#
# *   The dataset `df_no_outliers` is now robust against extreme values in 'PESO (Gramos)' and 'TALLA (CentImetros)', making it more suitable for statistical analysis or machine learning models that are sensitive to outliers.
# *   Consider visualizing the distribution of the removed outliers (e.g., their counts per category or other features) to understand if they represent data errors, rare events, or specific subgroups that might warrant separate analysis rather than outright removal.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for 'PESO (Gramos)' and 'TALLA (CentImetros)' after outlier removal
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df_no_outliers['PESO (Gramos)'], kde=True)
plt.title('Distribución de Peso (Gramos) sin Outliers')
plt.xlabel('Peso (Gramos)')
plt.ylabel('Frecuencia')

plt.subplot(1, 2, 2)
sns.histplot(df_no_outliers['TALLA (CentImetros)'], kde=True)
plt.title('Distribución de Talla (Centímetros) sin Outliers')
plt.xlabel('Talla (Centímetros)')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# Box plots for 'PESO (Gramos)' and 'TALLA (CentImetros)' after outlier removal
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(y=df_no_outliers['PESO (Gramos)'])
plt.title('Diagrama de Caja de Peso (Gramos) sin Outliers')
plt.ylabel('Peso (Gramos)')

plt.subplot(1, 2, 2)
sns.boxplot(y=df_no_outliers['TALLA (CentImetros)'])
plt.title('Diagrama de Caja de Talla (Centímetros) sin Outliers')
plt.ylabel('Talla (Centímetros)')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 6))

# Pie chart for SEXO
plt.subplot(1, 3, 1)
df_no_outliers['SEXO'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribución de Sexo')
plt.ylabel('') # Remove y-label for better aesthetics

# Pie chart for TIPO PARTO
plt.subplot(1, 3, 2)
df_no_outliers['TIPO PARTO'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribución de Tipo de Parto')
plt.ylabel('')

# Pie chart for PERTENENCIA ETNICA
plt.subplot(1, 3, 3)
df_no_outliers['PERTENENCIA ETNICA'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Distribución de Pertenencia Étnica')
plt.ylabel('')

plt.tight_layout()
plt.show()

# %%
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# --- Análisis de normalidad para 'PESO (Gramos)' ---
print("\n--- Análisis de normalidad para PESO (Gramos) ---")

# Shapiro-Wilk Test
stat, p = stats.shapiro(df_no_outliers['PESO (Gramos)'])
print('Shapiro-Wilk Test: Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Parece normal (No se rechaza H0)')
else:
    print('No parece normal (Se rechaza H0)')

# Kolmogorov-Smirnov Test
# For K-S test, we need to provide the parameters of the normal distribution (mean, std dev)
mean_peso = df_no_outliers['PESO (Gramos)'].mean()
std_peso = df_no_outliers['PESO (Gramos)'].std()
stat, p = stats.kstest(df_no_outliers['PESO (Gramos)'], 'norm', args=(mean_peso, std_peso))
print('Kolmogorov-Smirnov Test: Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Parece normal (No se rechaza H0)')
else:
    print('No parece normal (Se rechaza H0)')

# Anderson-Darling Test
result = stats.anderson(df_no_outliers['PESO (Gramos)'], dist='norm')
print('Anderson-Darling Test: Statistics=%.3f' % result.statistic)
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < cv:
        print('  Parece normal en el nivel de significancia del %.1f%% (crítico=%.3f)' % (sl, cv))
    else:
        print('  No parece normal en el nivel de significancia del %.1f%% (crítico=%.3f)' % (sl, cv))

# QQ-plot para PESO (Gramos)
sm.qqplot(df_no_outliers['PESO (Gramos)'], line='s')
plt.title('QQ-plot para PESO (Gramos)')
plt.show()

# --- Análisis de normalidad para 'TALLA (CentImetros)' ---
print("\n--- Análisis de normalidad para TALLA (CentImetros) ---")

# Shapiro-Wilk Test
stat, p = stats.shapiro(df_no_outliers['TALLA (CentImetros)'])
print('Shapiro-Wilk Test: Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Parece normal (No se rechaza H0)')
else:
    print('No parece normal (Se rechaza H0)')

# Kolmogorov-Smirnov Test
mean_talla = df_no_outliers['TALLA (CentImetros)'].mean()
std_talla = df_no_outliers['TALLA (CentImetros)'].std()
stat, p = stats.kstest(df_no_outliers['TALLA (CentImetros)'], 'norm', args=(mean_talla, std_talla))
print('Kolmogorov-Smirnov Test: Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Parece normal (No se rechaza H0)')
else:
    print('No parece normal (Se rechaza H0)')

# Anderson-Darling Test
result = stats.anderson(df_no_outliers['TALLA (CentImetros)'], dist='norm')
print('Anderson-Darling Test: Statistics=%.3f' % result.statistic)
for i in range(len(result.critical_values)):
    sl, cv = result.significance_level[i], result.critical_values[i]
    if result.statistic < cv:
        print('  Parece normal en el nivel de significancia del %.1f%% (crítico=%.3f)' % (sl, cv))
    else:
        print('  No parece normal en el nivel de significancia del %.1f%% (crítico=%.3f)' % (sl, cv))

# QQ-plot para TALLA (CentImetros)
sm.qqplot(df_no_outliers['TALLA (CentImetros)'], line='s')
plt.title('QQ-plot para TALLA (CentImetros)')
plt.show()
# Out:
# --- Análisis de normalidad para PESO (Gramos) ---
# Shapiro-Wilk Test: Statistics=0.996, p=0.000
# No parece normal (Se rechaza H0)
# Kolmogorov-Smirnov Test: Statistics=0.027, p=0.000
# No parece normal (Se rechaza H0)
# Anderson-Darling Test: Statistics=8.105
#   No parece normal en el nivel de significancia del 15.0% (crítico=0.576)
#   No parece normal en el nivel de significancia del 10.0% (crítico=0.656)
#   No parece normal en el nivel de significancia del 5.0% (crítico=0.787)
#   No parece normal en el nivel de significancia del 2.5% (crítico=0.918)
#   No parece normal en el nivel de significancia del 1.0% (crítico=1.091)
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8572.
#   res = hypotest_fun_out(*samples, **kwds)
# --- Análisis de normalidad para TALLA (CentImetros) ---
# Shapiro-Wilk Test: Statistics=0.970, p=0.000
# No parece normal (Se rechaza H0)
# Kolmogorov-Smirnov Test: Statistics=0.123, p=0.000
# No parece normal (Se rechaza H0)
# Anderson-Darling Test: Statistics=97.964
#   No parece normal en el nivel de significancia del 15.0% (crítico=0.576)
#   No parece normal en el nivel de significancia del 10.0% (crítico=0.656)
#   No parece normal en el nivel de significancia del 5.0% (crítico=0.787)
#   No parece normal en el nivel de significancia del 2.5% (crítico=0.918)
#   No parece normal en el nivel de significancia del 1.0% (crítico=1.091)

# %% [markdown]
# He analizado los resultados del test de normalidad para las variables de 'PESO (Gramos)' y 'TALLA (CentImetros)'.
#
# Para ambas variables, los tests de Shapiro-Wilk, Kolmogorov-Smirnov y Anderson-Darling indican que los datos no parecen seguir una distribución normal, ya que los valores p son muy bajos (0.000), rechazando la hipótesis nula de normalidad en todos los casos.
#
# Los gráficos QQ-plot también visualizan esta desviación de la normalidad, mostrando que los puntos no se alinean perfectamente con la línea teórica de una distribución normal. Aunque se eliminaron los outliers, la distribución subyacente de estas variables no es normal.
